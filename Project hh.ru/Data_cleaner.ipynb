# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Загрузка данных из файла 'results3' в DataFrame
file_path = 'for_cleaning2.csv'  # предполагая, что файл в формате CSV
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
list(df.columns.values)
# Out:
# ['Unnamed: 0',
#  'alternate_url',
#  'Организация:',
#  'Описание',
#  'Тип занятости',
#  'Локация',
#  'Ключевые навыки',
#  'name',
#  'salary',
#  'snippet',
#  'schedule',
#  'professional_roles',
#  'experience']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1712 entries, 0 to 1711
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1712 non-null   int64
#  1   alternate_url       1712 non-null   object
#  2   Организация:        1711 non-null   object
#  3   Описание            1711 non-null   object
#  4   Тип занятости       1711 non-null   object
#  5   Локация             1711 non-null   object
#  6   Ключевые навыки     1711 non-null   object
#  7   name                1712 non-null   object
#  8   salary              1712 non-null   object
#  9   snippet             1712 non-null   object
#  10  schedule            1712 non-null   object
#  11  professional_roles  1712 non-null   object
#  12  experience          1712 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 174.0+ KB

# %% [markdown]
# Преобразуем признаки

# %%
df['salary'] = df['salary'].apply(eval)
df = df.join(df['salary'].apply(pd.Series))
df = df.drop('salary', axis=1)
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df['professional_roles'] = df['professional_roles'].str.replace(']', '')
df['professional_roles'] = df['professional_roles'].str.replace('[', '')

# %%
df['professional_roles'] = df['professional_roles'].apply(eval)
df['professional_roles']
# Out:
# 0                          {'id': '40', 'name': 'Другое'}
# 1        {'id': '96', 'name': 'Программист, разработчик'}
# 2       {'id': '70', 'name': 'Менеджер по продажам, ме...
# 3        {'id': '96', 'name': 'Программист, разработчик'}
# 4        {'id': '96', 'name': 'Программист, разработчик'}
#                               ...
# 1707                 {'id': '124', 'name': 'Тестировщик'}
# 1708     {'id': '96', 'name': 'Программист, разработчик'}
# 1709     {'id': '96', 'name': 'Программист, разработчик'}
# 1710     {'id': '96', 'name': 'Программист, разработчик'}
# 1711     {'id': '96', 'name': 'Программист, разработчик'}
# Name: professional_roles, Length: 1712, dtype: object

# %%
df = df.join(df['professional_roles'].apply(pd.Series), how = 'left', lsuffix='left', rsuffix='right')

# %%
df = df.drop('professional_roles', axis=1)

# %%
df = df.rename(columns={'id':'id_professional_role'})

# %%
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df = df.rename(columns={'nameright':'professional_role'})
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df['snippet']
# Out:
# 0       {'requirement': 'Опыт работы на таких позициях...
# 1       {'requirement': 'Опыт разработки мобильных при...
# 2       {'requirement': 'Опыт работы на таких позициях...
# 3       {'requirement': 'Высшее образование. Качествен...
# 4       {'requirement': 'Python. PHP. HTML, CSS. JavaS...
#                               ...
# 1707    {'requirement': 'Опыт автоматизации тестирован...
# 1708    {'requirement': 'Опыт работы с RESTful API и и...
# 1709    {'requirement': 'Практическое знание синтаксис...
# 1710    {'requirement': 'Умение ориентироваться в чужо...
# 1711    {'requirement': 'Коммерческий опыт разработки ...
# Name: snippet, Length: 1712, dtype: object

# %%
df['snippet'] = df['snippet'].apply(eval)
df = df.join(df['snippet'].apply(pd.Series))
df = df.drop('snippet', axis=1)
df
# Out:
#       Unnamed: 0                   alternate_url  \
# 0              0  https://hh.ru/vacancy/97787105
# 1              1  https://hh.ru/vacancy/98305183
# 2              2  https://hh.ru/vacancy/97787182
# 3              3  https://hh.ru/vacancy/98594437
# 4              4  https://hh.ru/vacancy/98273601
# ...          ...                             ...
# 1707        1707  https://hh.ru/vacancy/97889559
# 1708        1708  https://hh.ru/vacancy/97815911
# 1709        1709  https://hh.ru/vacancy/98014421
# 1710        1710  https://hh.ru/vacancy/97695253
# 1711        1711  https://hh.ru/vacancy/95878315
#
#                                      Организация:  \
# 0                                         MPSTATS
# 1           Инновационная Экологическая Платформа
# 2                                         MPSTATS
# 3                                      НИТУ МИСИС
# 4                                ООО «Вин-Маркет»
# ...                                           ...
# ...

# %%
df['schedule']
# Out:
# 4           {'id': 'fullDay', 'name': 'Полный день'}
# 8       {'id': 'remote', 'name': 'Удаленная работа'}
# 11          {'id': 'fullDay', 'name': 'Полный день'}
# 16      {'id': 'remote', 'name': 'Удаленная работа'}
# 19          {'id': 'fullDay', 'name': 'Полный день'}
#                             ...
# 5296    {'id': 'remote', 'name': 'Удаленная работа'}
# 5297    {'id': 'remote', 'name': 'Удаленная работа'}
# 5300    {'id': 'remote', 'name': 'Удаленная работа'}
# 5302    {'id': 'remote', 'name': 'Удаленная работа'}
# 5307    {'id': 'remote', 'name': 'Удаленная работа'}
# Name: schedule, Length: 894, dtype: object

# %%
df['schedule'] = df['schedule'].apply(eval)
df = df.join(df['schedule'].apply(pd.Series))
df = df.drop('schedule', axis=1)
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df = df.rename(columns={'id':'id_schedule', 'name':'schedule'})
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df['experience'] = df['experience'].apply(eval)
df = df.join(df['experience'].apply(pd.Series))
df = df.drop('experience', axis=1)
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df = df.rename(columns={'id':'id_exp', 'name':'exp'})
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df[0] = df[0].apply(eval)
df = df.join(df[0].apply(pd.Series))
df = df.drop(0, axis=1)
df
# Out:
#                       alternate_url                           Организация:  \
# 0    https://hh.ru/vacancy/97787105                                MPSTATS
# 1    https://hh.ru/vacancy/98305183  Инновационная Экологическая Платформа
# 2    https://hh.ru/vacancy/98594437                             НИТУ МИСИС
# 3    https://hh.ru/vacancy/97787182                                MPSTATS
# 4    https://hh.ru/vacancy/98273601                       ООО «Вин-Маркет»
# ..                              ...                                    ...
# 889  https://hh.ru/vacancy/95950075                  Яндекс Крауд: Контент
# 890  https://hh.ru/vacancy/95867438                  Яндекс Крауд: Контент
# 891  https://hh.ru/vacancy/95950066                  Яндекс Крауд: Контент
# 892  https://hh.ru/vacancy/95950084                  Яндекс Крауд: Контент
# 893  https://hh.ru/vacancy/95950077                  Яндекс Крауд: Контент
#
# ...

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.head()
# Out:
#    Unnamed: 0                   alternate_url  \
# 0           0  https://hh.ru/vacancy/97787105
# 1           1  https://hh.ru/vacancy/98305183
# 2           2  https://hh.ru/vacancy/97787182
# 3           3  https://hh.ru/vacancy/98594437
# 4           4  https://hh.ru/vacancy/98273601
#
#                             Организация:  \
# 0                                MPSTATS
# 1  Инновационная Экологическая Платформа
# 2                                MPSTATS
# 3                             НИТУ МИСИС
# 4                       ООО «Вин-Маркет»
#
#                                             Описание Тип занятости  \
# 0  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 1  Ecoplatform - один из лидеров рынка фандоматов...     FULL_TIME
# 2  MPSTATS — лидирующий сервис аналитики маркетпл...     FULL_TIME
# 3  Университет науки и технологий МИСИС является ...     FULL_TIME
# 4  Кто мы: Aftermarket-DATA © — разработчик прогр...     FULL_TIME
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1712 entries, 0 to 1711
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1712 non-null   int64
#  1   alternate_url         1712 non-null   object
#  2   Организация:          1711 non-null   object
#  3   Описание              1711 non-null   object
#  4   Тип занятости         1711 non-null   object
#  5   Локация               1711 non-null   object
#  6   Ключевые навыки       1711 non-null   object
#  7   nameleft              1712 non-null   object
#  8   from                  1449 non-null   float64
#  9   to                    1021 non-null   float64
#  10  currency              1712 non-null   object
#  11  gross                 1712 non-null   bool
#  12  id_professional_role  1712 non-null   object
#  13  professional_role     1712 non-null   object
#  14  requirement           1696 non-null   object
# ...

# %%
#сохраним информацию о профессии и ее id в таблицу
role_decoder = df[['id_professional_role', 'professional_role']].drop_duplicates()

# %%
df.drop(columns=['Unnamed: 0', 'professional_role', 'exp', 'schedule', 'gross'], inplace=True)

# %%
df
# Out:
#                        alternate_url  \
# 0     https://hh.ru/vacancy/97787105
# 1     https://hh.ru/vacancy/98305183
# 2     https://hh.ru/vacancy/97787182
# 3     https://hh.ru/vacancy/98594437
# 4     https://hh.ru/vacancy/98273601
# ...                              ...
# 1707  https://hh.ru/vacancy/97889559
# 1708  https://hh.ru/vacancy/97815911
# 1709  https://hh.ru/vacancy/98014421
# 1710  https://hh.ru/vacancy/97695253
# 1711  https://hh.ru/vacancy/95878315
#
#                                      Организация:  \
# 0                                         MPSTATS
# 1           Инновационная Экологическая Платформа
# 2                                         MPSTATS
# 3                                      НИТУ МИСИС
# 4                                ООО «Вин-Маркет»
# ...                                           ...
# 1707  ГКУ Центр занятости населения города Москвы
# 1708                                     Синаптик
# 1709                                       Vortex
# ...

# %%
df.to_csv('final.csv')

# %%
role_decoder.to_csv('role_decoder.csv')
